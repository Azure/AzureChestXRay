# %% [markdown]
# # Using Microsoft AI to Build a Lung-Disease Prediction Model Using Chest X-Ray Images - Tutorial

# %% [markdown]
# ## Introduction

# %% [markdown]
# This Jupyter Notebook is the tutorial to walk people through how to build a lung-dissease prediction model using Chest X-ray Images. The full code is in this github repo (https://github.com/Azure/AzureChestXRay) and the blogpost is here (https://blogs.technet.microsoft.com/machinelearning/2018/03/07/using-microsoft-ai-to-build-a-lung-disease-prediction-model-using-chest-x-ray-images/)

# %% [markdown]
# This tutorial consists of a few parts:
# - Build a lung disease prediction model
# - Validate model and get metrics
# - Visulaizing the model result

# %% [markdown]
# Here are all the resources that are used in this
# - _Dataset_
#
#   - National Institutes of Health ( [NIH](https://www.nih.gov/)) chest x-ray dataset. This dataset is a  [publicly](https://www.nih.gov/news-events/news-releases/nih-clinical-center-provides-one-largest-publicly-available-chest-x-ray-datasets-scientific-community)  [available](https://nihcc.app.box.com/v/ChestXray-NIHCC) and medically  [curated](http://openaccess.thecvf.com/content_cvpr_2017/papers/Wang_ChestX-ray8_Hospital-Scale_Chest_CVPR_2017_paper.pdf) dataset.
#
# - _Technique_
#
#   - State-of-the art  [DenseNet](https://arxiv.org/pdf/1608.06993.pdf) for image classification. DenseNet is an open-source deep learning algorithm with implementations available in  [Keras](https://github.com/keras-team/keras-contrib/blob/master/keras_contrib/applications/densenet.py) (using  [TensorFlow](https://www.tensorflow.org/) as a back-end). We also explored the  [PyTorch](http://pytorch.org/) version of DenseNet.
#
#   - [Class Activation Maps](http://cnnlocalization.csail.mit.edu/) are used to understand model activation and visualize it.
#
# - _Tools and Platforms_
#
#   - [Deep Learning VMs with GPU acceleration](https://docs.microsoft.com/en-us/azure/machine-learning/data-science-virtual-machine/deep-learning-dsvm-overview) are used as the compute environment.
#
#   - [Azure Machine Learning](https://azure.microsoft.com/en-us/services/machine-learning-services/) is used as a managed machine learning service for project management, run history and version control, and model deployment.

# %% [markdown]
# The  [source code we provide on GitHub](https://github.com/Azure/AzureChestXRay) allows you to build the x-ray image pathology classification system in less than an hour using the model pretrained on ChestX-ray14 data. If needed, one can also recreate and expand the full multi-GPU training pipeline starting with a model pretrained using the  [ImageNet](http://image-net.org/) dataset.
#
# The source code, tools, and discussion below are provided to assist data scientists in understanding the potential for developing deep learning -driven intelligent applications using Azure AI services and are intended for research and development use only. The x-ray image pathology classification system is not intended for use in clinical diagnosis or clinical decision-making or for any other clinical use. The performance of this model for clinical use has not been established.

# %% [markdown]
# ### Downloading nececcary packages and data
# We will install a few packages that will be required later on. We will also download a small portion of data (1% of the original dataset) for tutorial purpose.

# %%
# %%capture
# !pip3 install git+https://github.com/onnx/onnxmltools
# !pip3 install git+https://www.github.com/keras-team/keras-contrib.git
# !pip3 install git+https://github.com/apple/coremltools

# %%
import os
import re
import timeit

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"  # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"] = "0"


import cv2
import keras
import keras.backend as K
import numpy as np
import pandas as pd
import tqdm
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from keras.layers import Dense, Input, GlobalAveragePooling2D, Flatten
from keras.models import Model
from keras.optimizers import Adam
from keras.utils import Sequence
from keras_contrib.applications.densenet import DenseNetImageNet121
from tensorflow.python.client import device_lib
import onnxmltools
from sklearn import metrics
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import pathlib
# Out:
# Using TensorFlow backend.

# %%
# TODO change this to be user name based
import getpass
username = getpass.getuser()
data_path = os.path.join("/mnt/", username)
print("root folder for all the data would be", data_path)
pathlib.Path(data_path).mkdir(parents=True, exist_ok=True) 
images_path = os.path.join(data_path, 'images.zip')
images_extracted_path = os.path.join(data_path, 'images')
pre_trained_model_path = os.path.join(data_path, 'chexray_14_weights_712split_epoch_054_val_loss_191.2588.hdf5')
label_path = os.path.join(data_path, 'Data_Entry_2017.csv')

# global variables
tensorboard_dir = os.path.join(data_path, 'tensorboard')
weights_dir = os.path.join(data_path, 'modelweights')
weights_file = weights_dir + 'chexnet_14_weights_712split_epoch_{epoch:03d}_val_loss_{val_loss:.4f}_withoutDenseLayers.hdf5'


#onnx model path
onnx_model_save_path = os.path.join(data_path, 'chestxray.onnx')
# Out:
# root folder for all the data would be /mnt/xiaoyzhu

# %% [markdown]
# # Dataset introduction and download sample data
# We use a weakly labelled dataset that was released by the NIH a few months ago. The dataset is described in  [this paper](https://arxiv.org/abs/1705.02315), and you can download it from  [here](https://nihcc.app.box.com/v/ChestXray-NIHCC). It includes over 30,805 unique patients and 112,120 frontal-view X-ray images with 14 different pathology labels (e.g. atelectasis, pneumonia, etc.) mined from radiology reports using NLP methods such as keyword search and semantic data integration. The NIH-released data also has 983 hand-labelled images covering 8 pathologies, which can be considered as strong labels. We train our model excluding those human labelled data and will use them for later visualization.

# %%
from requests import get  # to make GET request

def download(url, file_name):
    # open in binary mode
    with open(file_name, "wb") as file:
        # get request
        response = get(url)
        # write to file
        file.write(response.content)

download('https://chestxray.blob.core.windows.net/chestxraytutorial/tutorial_xray/images.zip', images_path)
download('https://chestxray.blob.core.windows.net/chestxraytutorial/tutorial_xray/Data_Entry_2017.csv', label_path)
download('https://chestxray.blob.core.windows.net/chestxraytutorial/tutorial_xray/chexray_14_weights_712split_epoch_054_val_loss_191.2588.hdf5', pre_trained_model_path)

# %%
import zipfile
with zipfile.ZipFile(images_path,"r") as zip_ref:
    zip_ref.extractall(images_extracted_path)

# %%
img = mpimg.imread(os.path.join(data_path, 'images','00000700_000.png'))
plt.figure(figsize=(8,8))
imgplot = plt.imshow(img, cmap='gray')

# %%
total_patient_number = 100
patient_id_original = [i for i in range(700, 800)]


name_list = ['Atelectasis', 'Cardiomegaly', 'Effusion', 'Infiltration', 'Mass', 'Nodule', 'Pneumonia', 'Pneumothorax',
             'Consolidation', 'Edema', 'Emphysema', 'Fibrosis', 'Pleural_Thickening', 'Hernia']

labels_df = pd.read_csv(label_path)

patient_id = patient_id_original
print("len of patient id is", len(patient_id))

print("first ten patient ids are", patient_id[:10])

# training:valid:test 7:1:2
patient_id_train = patient_id[:int(total_patient_number * 0.7)]
patient_id_valid = patient_id[int(total_patient_number * 0.7):int(total_patient_number * 0.8)]
# get the rest of the patient_id as the test set
patient_id_test = patient_id[int(total_patient_number * 0.8):]

print("train, valid, test patients numbers are:", len(patient_id_train), len(patient_id_valid), len(patient_id_test))


def process_data(current_df, patient_ids):
    image_name_index = []
    image_labels = {}
    for individual_patient in tqdm.tqdm(patient_ids):
        for _, row in current_df[current_df['Patient ID'] == individual_patient].iterrows():
            processed_image_name = row['Image Index']
            image_name_index.append(processed_image_name)
            image_labels[processed_image_name] = np.zeros(14, dtype=np.uint8)
            for disease_index, ele in enumerate(name_list):
                if re.search(ele, row['Finding Labels'], re.IGNORECASE):
                    image_labels[processed_image_name][disease_index] = 1
                else:
                    # redundant code but just to make it more readable
                    image_labels[processed_image_name][disease_index] = 0
                # print("processed", row['Image Index'])
    return image_name_index, image_labels


train_data_index, train_labels = process_data(labels_df, patient_id_train)
valid_data_index, valid_labels = process_data(labels_df, patient_id_valid)
test_data_index, test_labels = process_data(labels_df, patient_id_test)

print("train, valid, test image number is:", len(train_data_index), len(valid_data_index), len(test_data_index))

# save the data
labels_all = {}
labels_all.update(train_labels)
labels_all.update(valid_labels)
labels_all.update(test_labels)

partition_dict = {'train': train_data_index, 'test': test_data_index, 'valid': valid_data_index}
# Out:
# 100%|██████████| 70/70 [00:00<00:00, 643.60it/s]
# 100%|██████████| 10/10 [00:00<00:00, 725.91it/s]
# 100%|██████████| 20/20 [00:00<00:00, 566.41it/s]
# len of patient id is 100
# first ten patient ids are [700, 701, 702, 703, 704, 705, 706, 707, 708, 709]
# train, valid, test patients numbers are: 70 10 20
# train, valid, test image number is: 257 25 99

# %% [markdown]
# # Defining the input pipeline
# We want to define the input pipeline, so that all the transformation (such as resizing the images) can be done and will be put in a queue, which is ready to be served on GPUs
#
# A few other settings:
# - Learning rate set to 0.01
# - Learning rate decays by 10 if the training loss does not decrease for 5 consecutive epochs
# - Train/validation/test dataset: 7:1:2
# - Using Adam optimizer and using standard parameters
# - Sigmoid function as the output since this is a multi-label problem and binary cross entropy as the loss function
# - Training for 100 epochs and select the one with smallest validation loss (In this tutorial we only train 2 epochs)

# %%
initial_lr = 0.001
resized_height = 224
resized_width = 224
num_channel = 3
num_classes = 14
epochs = 2
batch_size = 16


# generator for train and validation data
# use the Sequence class per issue https://github.com/keras-team/keras/issues/1638
class DataGenSequence(Sequence):
    def __init__(self, labels, image_file_index, current_state):
        self.batch_size = batch_size
        self.labels = labels
        self.img_file_index = image_file_index
        self.current_state = current_state
        self.len = len(self.img_file_index) // self.batch_size
        self.labels_df = pd.read_csv(label_path)
        self.entry_times = 0
        print("for DataGenSequence", current_state, "total rows are:", len(self.img_file_index), ", len is", self.len)

    def __len__(self):
        return self.len

    def __getitem__(self, idx):
        start_time = timeit.default_timer()
        # make sure each batch size has the same amount of data
        current_batch = self.img_file_index[idx * self.batch_size: (idx + 1) * self.batch_size]
        X = np.empty((self.batch_size, resized_height, resized_width, num_channel))
        y = np.empty((self.batch_size, num_classes))

        for i, image_name in enumerate(current_batch):
            path = os.path.join(images_extracted_path, image_name)
            if not os.path.exists(path):
                print(path)
            x = cv2.imread(path)
            img = cv2.resize(cv2.imread(path), (resized_height, resized_width)).astype(np.float32)

            X[i, :, :, :] = img
            y[i, :] = labels[image_name]

            # only do random flipping in training status
            x_augmented = X

        # code you want to evaluate
        self.entry_times += 1
        elapsed = timeit.default_timer() - start_time
        return x_augmented, y

# %% [markdown]
# # Network Architecture (DenseNet)
#
# Deep neural networks are notoriously hard to train well, especially when the neural networks get deeper. Inspired by the  [Stanford team](https://stanfordmlgroup.github.io/projects/chexnet/), we use the [DenseNet](https://arxiv.org/abs/1608.06993)-121 architecture with pre-trained weights from ImageNet as initialization parameters. This allows us to both pass the gradient more efficiently and train a deeper model. This architecture alleviates the vanishing-gradient problem and enables feature map reuse, which makes it possible to train very deep neural networks.
#
# ![image.png](attachment:image.png)
#
# We will  use 100 patients for testing purpose, which is around 1% of the total dataset.

# %%
def build_model():
    """

    Returns: a model with specified weights

    """
    # define the model, use pre-trained weights for image_net
    base_model = DenseNetImageNet121(input_shape=(resized_height, resized_width, num_channel),
                                     weights='imagenet',
                                     include_top=False,
                                     pooling='avg')

    x = base_model.output
    x = Dense(100, activation='relu')(x)
    predictions = Dense(14, activation='sigmoid', name="final_classifier")(x)
    model = Model(inputs=base_model.input, outputs=predictions)
    return model


# loss function
def unweighted_binary_crossentropy(y_true, y_pred):
    """
    Args:
        y_true: true labels
        y_pred: predicted labels

    Returns: the sum of binary cross entropy loss across all the classes

    """
    return K.sum(K.binary_crossentropy(y_true, y_pred))

# %% [markdown]
# # Build and Run the model

# %%
model_gpu = build_model()
model_checkpoint = ModelCheckpoint(
    weights_file,
    monitor='val_loss', save_weights_only=False)

num_workers = 6

model_gpu.compile(optimizer=Adam(lr=initial_lr), loss=unweighted_binary_crossentropy)

reduce_lr_on_plateau = ReduceLROnPlateau(monitor='val_loss', factor=0.33333, patience=5, verbose=1, min_lr=1e-4)

tensor_board = TensorBoard(log_dir=tensorboard_dir)
callbacks = [model_checkpoint, reduce_lr_on_plateau, tensor_board]

labels = labels_all
partition = partition_dict

model_gpu.fit_generator(generator=DataGenSequence(labels, partition['train'], current_state='train'),
                              # steps_per_epoch=100,
                              epochs=epochs,
                              verbose=1,
                              callbacks=callbacks,
                              workers=num_workers,
                              # validation_steps=100,
                              # max_queue_size=32,
                              shuffle=False,
                              validation_data=DataGenSequence(labels, partition['valid'], current_state='validation')
                              # validation_steps=1
                              )
# Out:
# Weights for the model were loaded successfully
# for DataGenSequence train total rows are: 257 , len is 16
# for DataGenSequence validation total rows are: 25 , len is 1
# Epoch 1/2
# 16/16 [==============================] - 114s 7s/step - loss: 69.2943 - val_loss: 114.5129
# Epoch 2/2
# 16/16 [==============================] - 93s 6s/step - loss: 48.0282 - val_loss: 526.8941

# %% [markdown]
# # Testing the actual model to get AUROC score
#
#
# We use ROC (Receiver Operating Characteristic) and the AUC score (area under ROC curve) as the final metric
# The reason is that medical dataset is usually highly unbalanced (for example Pneumonia only accounts for 1/77 of the data), and ROC can have a good balance between the True Positive Rate and the False Negative Rate
#
# We don’t use accuracy here as accuracy usually don’t make sense
#
# Note the score will be very high since 1) the test set is very small for experimentation purpose; 2) the pre-trained model was trained using a random set of data which includes a lot of the testing data. The actual AUROC is around 0.845
#
# ![image.png](attachment:image.png)

# %%
# load test data
X_test = np.empty((len(partition['test']), 224, 224, 3), dtype=np.float32)
y_test = np.empty((len(partition['test']) - len(partition['test']) % batch_size, 14), dtype=np.float32)

for i, npy in enumerate(partition['test']):
    if (i < len(y_test)):
        # round to batch_size
        y_test[i, :] = labels[npy]

print("len of result is", len(y_test))
y_pred_list = np.empty((len(partition['test']), 14), dtype=np.float32)

# individual models

print(pre_trained_model_path)
#    model = load_model(current_model_file)
model = keras.models.load_model(pre_trained_model_path)

print('evaluation for model', pre_trained_model_path)
# y_pred = model.predict(X_test)

y_pred = model.predict_generator(generator=DataGenSequence(labels, partition['test'], current_state='test'),
                                 workers=32, verbose=1, max_queue_size=1)
print("result shape", y_pred.shape)

# add one fake row of ones in both test and pred values to avoid:
# ValueError: Only one class present in y_true. ROC AUC score is not defined in that case.
y_test = np.insert(y_test, 0, np.ones((y_test.shape[1],)), 0)
y_pred = np.insert(y_pred, 0, np.ones((y_pred.shape[1],)), 0)

df = pd.DataFrame(columns=['Disease', 'Our AUC Score'])
for d in range(14):
    df.loc[d] = [name_list[d],
                 metrics.roc_auc_score(y_test[:, d], y_pred[:, d])]

print(df)
# Out:
# len of result is 96
# /mnt/xiaoyzhu/chexray_14_weights_712split_epoch_054_val_loss_191.2588.hdf5
# /home/xiaoyzhu/.local/lib/python3.5/site-packages/keras/engine/saving.py:270: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
# evaluation for model /mnt/xiaoyzhu/chexray_14_weights_712split_epoch_054_val_loss_191.2588.hdf5
# for DataGenSequence test total rows are: 99 , len is 6
# 6/6 [==============================] - 13s 2s/step
# result shape (96, 14)
#                Disease  Our AUC Score
# 0          Atelectasis       0.946809
# 1         Cardiomegaly       0.994624
# 2             Effusion       0.968288
# 3         Infiltration       0.736786
# 4                 Mass       1.000000
# 5               Nodule       0.817460
# 6            Pneumonia       0.978947
# 7         Pneumothorax       1.000000
# 8        Consolidation       0.721987
# 9                Edema       1.000000
# 10           Emphysema       1.000000
# 11            Fibrosis       0.968421
# 12  Pleural_Thickening       0.926316
# 13              Hernia       1.000000

# %% [markdown]
# This is the actual AUROC score we get for the model running on actual test dataset:
#
# | Disease | AUC Score | Disease | AUC Score |
# | --- | --- | --- | --- |
# | Atelectasis | 0.828543 | Pneumothorax | 0.881838 |
# | Cardiomegaly | 0.891449 | Consolidation | 0.721818 |
# | Effusion | 0.817697 | Edema | 0.868002 |
# | Infiltration | 0.907302 | Emphysema | 0.787202 |
# | Mass | 0.895815 | Fibrosis | 0.826822 |
# | Nodule | 0.907841 | Pleural Thickening | 0.793416 |
# | Pneumonia | 0.817601 | Hernia | 0.889089 |

# %% [markdown]
# # Visualizing the models (Class Activation Mapping)
#
# Individual prediction activation maps like Class Activation Mapping ( [CAM](http://cnnlocalization.csail.mit.edu/)) images allow one to understand what the model learns and thus explain a prediction/score. CAM methods are useful to help understand and explain model predictions. Aside from explaining model output, CAM images can also be used for model improvement through guided training. For example, one can modify the training data by removing (or relabeling) areas in the image that should not be the focus for prediction.
#
# We use CAM visualization to understand how to interpret the classification results for new chest X-ray images. The cardiomegaly pathology bounding box from the NIH annotated data and peak CAM image show a good visual overlap, indicating that the model focuses on the right area of the image when issuing the prediction.

# %%
model.summary()
# replace mode weights with the ones computing by training in chest xray
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# initial_conv2D (Conv2D)         (None, 112, 112, 64) 9408        input_1[0][0]
# __________________________________________________________________________________________________
# initial_bn (BatchNormalization) (None, 112, 112, 64) 256         initial_conv2D[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 112, 112, 64) 0           initial_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# dense_0_0_bn (BatchNormalizatio (None, 56, 56, 64)   256         max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 56, 56, 64)   0           dense_0_0_bn[0][0]
# __________________________________________________________________________________________________
# dense_0_0_bottleneck_conv2D (Co (None, 56, 56, 128)  8192        activation_2[0][0]
# __________________________________________________________________________________________________
# dense_0_0_bottleneck_bn (BatchN (None, 56, 56, 128)  512         dense_0_0_bottleneck_conv2D[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 56, 56, 128)  0           dense_0_0_bottleneck_bn[0][0]
# __________________________________________________________________________________________________
# dense_0_0_conv2D (Conv2D)       (None, 56, 56, 32)   36864       activation_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 56, 56, 96)   0           max_pooling2d_1[0][0]
#                                                                  dense_0_0_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_0_1_bn (BatchNormalizatio (None, 56, 56, 96)   384         concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 56, 56, 96)   0           dense_0_1_bn[0][0]
# __________________________________________________________________________________________________
# dense_0_1_bottleneck_conv2D (Co (None, 56, 56, 128)  12288       activation_4[0][0]
# __________________________________________________________________________________________________
# dense_0_1_bottleneck_bn (BatchN (None, 56, 56, 128)  512         dense_0_1_bottleneck_conv2D[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 56, 56, 128)  0           dense_0_1_bottleneck_bn[0][0]
# __________________________________________________________________________________________________
# dense_0_1_conv2D (Conv2D)       (None, 56, 56, 32)   36864       activation_5[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 56, 56, 128)  0           concatenate_1[0][0]
#                                                                  dense_0_1_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_0_2_bn (BatchNormalizatio (None, 56, 56, 128)  512         concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 56, 56, 128)  0           dense_0_2_bn[0][0]
# __________________________________________________________________________________________________
# dense_0_2_bottleneck_conv2D (Co (None, 56, 56, 128)  16384       activation_6[0][0]
# __________________________________________________________________________________________________
# dense_0_2_bottleneck_bn (BatchN (None, 56, 56, 128)  512         dense_0_2_bottleneck_conv2D[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 56, 56, 128)  0           dense_0_2_bottleneck_bn[0][0]
# __________________________________________________________________________________________________
# dense_0_2_conv2D (Conv2D)       (None, 56, 56, 32)   36864       activation_7[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 56, 56, 160)  0           concatenate_2[0][0]
#                                                                  dense_0_2_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_0_3_bn (BatchNormalizatio (None, 56, 56, 160)  640         concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 56, 56, 160)  0           dense_0_3_bn[0][0]
# __________________________________________________________________________________________________
# dense_0_3_bottleneck_conv2D (Co (None, 56, 56, 128)  20480       activation_8[0][0]
# __________________________________________________________________________________________________
# dense_0_3_bottleneck_bn (BatchN (None, 56, 56, 128)  512         dense_0_3_bottleneck_conv2D[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 56, 56, 128)  0           dense_0_3_bottleneck_bn[0][0]
# __________________________________________________________________________________________________
# dense_0_3_conv2D (Conv2D)       (None, 56, 56, 32)   36864       activation_9[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 56, 56, 192)  0           concatenate_3[0][0]
#                                                                  dense_0_3_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_0_4_bn (BatchNormalizatio (None, 56, 56, 192)  768         concatenate_4[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 56, 56, 192)  0           dense_0_4_bn[0][0]
# __________________________________________________________________________________________________
# dense_0_4_bottleneck_conv2D (Co (None, 56, 56, 128)  24576       activation_10[0][0]
# __________________________________________________________________________________________________
# dense_0_4_bottleneck_bn (BatchN (None, 56, 56, 128)  512         dense_0_4_bottleneck_conv2D[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 56, 56, 128)  0           dense_0_4_bottleneck_bn[0][0]
# __________________________________________________________________________________________________
# dense_0_4_conv2D (Conv2D)       (None, 56, 56, 32)   36864       activation_11[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 56, 56, 224)  0           concatenate_4[0][0]
#                                                                  dense_0_4_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_0_5_bn (BatchNormalizatio (None, 56, 56, 224)  896         concatenate_5[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 56, 56, 224)  0           dense_0_5_bn[0][0]
# __________________________________________________________________________________________________
# dense_0_5_bottleneck_conv2D (Co (None, 56, 56, 128)  28672       activation_12[0][0]
# __________________________________________________________________________________________________
# dense_0_5_bottleneck_bn (BatchN (None, 56, 56, 128)  512         dense_0_5_bottleneck_conv2D[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 56, 56, 128)  0           dense_0_5_bottleneck_bn[0][0]
# __________________________________________________________________________________________________
# dense_0_5_conv2D (Conv2D)       (None, 56, 56, 32)   36864       activation_13[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 56, 56, 256)  0           concatenate_5[0][0]
#                                                                  dense_0_5_conv2D[0][0]
# __________________________________________________________________________________________________
# tr_0_bn (BatchNormalization)    (None, 56, 56, 256)  1024        concatenate_6[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 56, 56, 256)  0           tr_0_bn[0][0]
# __________________________________________________________________________________________________
# tr_0_conv2D (Conv2D)            (None, 56, 56, 128)  32768       activation_14[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 28, 28, 128)  0           tr_0_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_1_0_bn (BatchNormalizatio (None, 28, 28, 128)  512         average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 28, 28, 128)  0           dense_1_0_bn[0][0]
# __________________________________________________________________________________________________
# dense_1_0_bottleneck_conv2D (Co (None, 28, 28, 128)  16384       activation_15[0][0]
# __________________________________________________________________________________________________
# dense_1_0_bottleneck_bn (BatchN (None, 28, 28, 128)  512         dense_1_0_bottleneck_conv2D[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 28, 28, 128)  0           dense_1_0_bottleneck_bn[0][0]
# __________________________________________________________________________________________________
# dense_1_0_conv2D (Conv2D)       (None, 28, 28, 32)   36864       activation_16[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 28, 28, 160)  0           average_pooling2d_1[0][0]
#                                                                  dense_1_0_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_1_1_bn (BatchNormalizatio (None, 28, 28, 160)  640         concatenate_7[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 28, 28, 160)  0           dense_1_1_bn[0][0]
# __________________________________________________________________________________________________
# dense_1_1_bottleneck_conv2D (Co (None, 28, 28, 128)  20480       activation_17[0][0]
# __________________________________________________________________________________________________
# dense_1_1_bottleneck_bn (BatchN (None, 28, 28, 128)  512         dense_1_1_bottleneck_conv2D[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 28, 28, 128)  0           dense_1_1_bottleneck_bn[0][0]
# __________________________________________________________________________________________________
# dense_1_1_conv2D (Conv2D)       (None, 28, 28, 32)   36864       activation_18[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 28, 28, 192)  0           concatenate_7[0][0]
#                                                                  dense_1_1_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_1_2_bn (BatchNormalizatio (None, 28, 28, 192)  768         concatenate_8[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 28, 28, 192)  0           dense_1_2_bn[0][0]
# __________________________________________________________________________________________________
# dense_1_2_bottleneck_conv2D (Co (None, 28, 28, 128)  24576       activation_19[0][0]
# __________________________________________________________________________________________________
# dense_1_2_bottleneck_bn (BatchN (None, 28, 28, 128)  512         dense_1_2_bottleneck_conv2D[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 28, 28, 128)  0           dense_1_2_bottleneck_bn[0][0]
# __________________________________________________________________________________________________
# dense_1_2_conv2D (Conv2D)       (None, 28, 28, 32)   36864       activation_20[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 28, 28, 224)  0           concatenate_8[0][0]
#                                                                  dense_1_2_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_1_3_bn (BatchNormalizatio (None, 28, 28, 224)  896         concatenate_9[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 28, 28, 224)  0           dense_1_3_bn[0][0]
# __________________________________________________________________________________________________
# dense_1_3_bottleneck_conv2D (Co (None, 28, 28, 128)  28672       activation_21[0][0]
# __________________________________________________________________________________________________
# dense_1_3_bottleneck_bn (BatchN (None, 28, 28, 128)  512         dense_1_3_bottleneck_conv2D[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 28, 28, 128)  0           dense_1_3_bottleneck_bn[0][0]
# __________________________________________________________________________________________________
# dense_1_3_conv2D (Conv2D)       (None, 28, 28, 32)   36864       activation_22[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 28, 28, 256)  0           concatenate_9[0][0]
#                                                                  dense_1_3_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_1_4_bn (BatchNormalizatio (None, 28, 28, 256)  1024        concatenate_10[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 28, 28, 256)  0           dense_1_4_bn[0][0]
# __________________________________________________________________________________________________
# dense_1_4_bottleneck_conv2D (Co (None, 28, 28, 128)  32768       activation_23[0][0]
# __________________________________________________________________________________________________
# dense_1_4_bottleneck_bn (BatchN (None, 28, 28, 128)  512         dense_1_4_bottleneck_conv2D[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 28, 28, 128)  0           dense_1_4_bottleneck_bn[0][0]
# __________________________________________________________________________________________________
# dense_1_4_conv2D (Conv2D)       (None, 28, 28, 32)   36864       activation_24[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 28, 28, 288)  0           concatenate_10[0][0]
#                                                                  dense_1_4_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_1_5_bn (BatchNormalizatio (None, 28, 28, 288)  1152        concatenate_11[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 28, 28, 288)  0           dense_1_5_bn[0][0]
# __________________________________________________________________________________________________
# dense_1_5_bottleneck_conv2D (Co (None, 28, 28, 128)  36864       activation_25[0][0]
# __________________________________________________________________________________________________
# dense_1_5_bottleneck_bn (BatchN (None, 28, 28, 128)  512         dense_1_5_bottleneck_conv2D[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 28, 28, 128)  0           dense_1_5_bottleneck_bn[0][0]
# __________________________________________________________________________________________________
# dense_1_5_conv2D (Conv2D)       (None, 28, 28, 32)   36864       activation_26[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 28, 28, 320)  0           concatenate_11[0][0]
#                                                                  dense_1_5_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_1_6_bn (BatchNormalizatio (None, 28, 28, 320)  1280        concatenate_12[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 28, 28, 320)  0           dense_1_6_bn[0][0]
# __________________________________________________________________________________________________
# dense_1_6_bottleneck_conv2D (Co (None, 28, 28, 128)  40960       activation_27[0][0]
# __________________________________________________________________________________________________
# dense_1_6_bottleneck_bn (BatchN (None, 28, 28, 128)  512         dense_1_6_bottleneck_conv2D[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 28, 28, 128)  0           dense_1_6_bottleneck_bn[0][0]
# __________________________________________________________________________________________________
# dense_1_6_conv2D (Conv2D)       (None, 28, 28, 32)   36864       activation_28[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 28, 28, 352)  0           concatenate_12[0][0]
#                                                                  dense_1_6_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_1_7_bn (BatchNormalizatio (None, 28, 28, 352)  1408        concatenate_13[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 28, 28, 352)  0           dense_1_7_bn[0][0]
# __________________________________________________________________________________________________
# dense_1_7_bottleneck_conv2D (Co (None, 28, 28, 128)  45056       activation_29[0][0]
# __________________________________________________________________________________________________
# dense_1_7_bottleneck_bn (BatchN (None, 28, 28, 128)  512         dense_1_7_bottleneck_conv2D[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 28, 28, 128)  0           dense_1_7_bottleneck_bn[0][0]
# __________________________________________________________________________________________________
# dense_1_7_conv2D (Conv2D)       (None, 28, 28, 32)   36864       activation_30[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 28, 28, 384)  0           concatenate_13[0][0]
#                                                                  dense_1_7_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_1_8_bn (BatchNormalizatio (None, 28, 28, 384)  1536        concatenate_14[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 28, 28, 384)  0           dense_1_8_bn[0][0]
# __________________________________________________________________________________________________
# dense_1_8_bottleneck_conv2D (Co (None, 28, 28, 128)  49152       activation_31[0][0]
# __________________________________________________________________________________________________
# dense_1_8_bottleneck_bn (BatchN (None, 28, 28, 128)  512         dense_1_8_bottleneck_conv2D[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 28, 28, 128)  0           dense_1_8_bottleneck_bn[0][0]
# __________________________________________________________________________________________________
# dense_1_8_conv2D (Conv2D)       (None, 28, 28, 32)   36864       activation_32[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 28, 28, 416)  0           concatenate_14[0][0]
#                                                                  dense_1_8_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_1_9_bn (BatchNormalizatio (None, 28, 28, 416)  1664        concatenate_15[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 28, 28, 416)  0           dense_1_9_bn[0][0]
# __________________________________________________________________________________________________
# dense_1_9_bottleneck_conv2D (Co (None, 28, 28, 128)  53248       activation_33[0][0]
# __________________________________________________________________________________________________
# dense_1_9_bottleneck_bn (BatchN (None, 28, 28, 128)  512         dense_1_9_bottleneck_conv2D[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 28, 28, 128)  0           dense_1_9_bottleneck_bn[0][0]
# __________________________________________________________________________________________________
# dense_1_9_conv2D (Conv2D)       (None, 28, 28, 32)   36864       activation_34[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 28, 28, 448)  0           concatenate_15[0][0]
#                                                                  dense_1_9_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_1_10_bn (BatchNormalizati (None, 28, 28, 448)  1792        concatenate_16[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 28, 28, 448)  0           dense_1_10_bn[0][0]
# __________________________________________________________________________________________________
# dense_1_10_bottleneck_conv2D (C (None, 28, 28, 128)  57344       activation_35[0][0]
# __________________________________________________________________________________________________
# dense_1_10_bottleneck_bn (Batch (None, 28, 28, 128)  512         dense_1_10_bottleneck_conv2D[0][0
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 28, 28, 128)  0           dense_1_10_bottleneck_bn[0][0]
# __________________________________________________________________________________________________
# dense_1_10_conv2D (Conv2D)      (None, 28, 28, 32)   36864       activation_36[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 28, 28, 480)  0           concatenate_16[0][0]
#                                                                  dense_1_10_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_1_11_bn (BatchNormalizati (None, 28, 28, 480)  1920        concatenate_17[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 28, 28, 480)  0           dense_1_11_bn[0][0]
# __________________________________________________________________________________________________
# dense_1_11_bottleneck_conv2D (C (None, 28, 28, 128)  61440       activation_37[0][0]
# __________________________________________________________________________________________________
# dense_1_11_bottleneck_bn (Batch (None, 28, 28, 128)  512         dense_1_11_bottleneck_conv2D[0][0
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 28, 28, 128)  0           dense_1_11_bottleneck_bn[0][0]
# __________________________________________________________________________________________________
# dense_1_11_conv2D (Conv2D)      (None, 28, 28, 32)   36864       activation_38[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 28, 28, 512)  0           concatenate_17[0][0]
#                                                                  dense_1_11_conv2D[0][0]
# __________________________________________________________________________________________________
# tr_1_bn (BatchNormalization)    (None, 28, 28, 512)  2048        concatenate_18[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 28, 28, 512)  0           tr_1_bn[0][0]
# __________________________________________________________________________________________________
# tr_1_conv2D (Conv2D)            (None, 28, 28, 256)  131072      activation_39[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 14, 14, 256)  0           tr_1_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_2_0_bn (BatchNormalizatio (None, 14, 14, 256)  1024        average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 14, 14, 256)  0           dense_2_0_bn[0][0]
# __________________________________________________________________________________________________
# dense_2_0_bottleneck_conv2D (Co (None, 14, 14, 128)  32768       activation_40[0][0]
# __________________________________________________________________________________________________
# dense_2_0_bottleneck_bn (BatchN (None, 14, 14, 128)  512         dense_2_0_bottleneck_conv2D[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 14, 14, 128)  0           dense_2_0_bottleneck_bn[0][0]
# __________________________________________________________________________________________________
# dense_2_0_conv2D (Conv2D)       (None, 14, 14, 32)   36864       activation_41[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 14, 14, 288)  0           average_pooling2d_2[0][0]
#                                                                  dense_2_0_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_2_1_bn (BatchNormalizatio (None, 14, 14, 288)  1152        concatenate_19[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 14, 14, 288)  0           dense_2_1_bn[0][0]
# __________________________________________________________________________________________________
# dense_2_1_bottleneck_conv2D (Co (None, 14, 14, 128)  36864       activation_42[0][0]
# __________________________________________________________________________________________________
# dense_2_1_bottleneck_bn (BatchN (None, 14, 14, 128)  512         dense_2_1_bottleneck_conv2D[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 14, 14, 128)  0           dense_2_1_bottleneck_bn[0][0]
# __________________________________________________________________________________________________
# dense_2_1_conv2D (Conv2D)       (None, 14, 14, 32)   36864       activation_43[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 14, 14, 320)  0           concatenate_19[0][0]
#                                                                  dense_2_1_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_2_2_bn (BatchNormalizatio (None, 14, 14, 320)  1280        concatenate_20[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 14, 14, 320)  0           dense_2_2_bn[0][0]
# __________________________________________________________________________________________________
# dense_2_2_bottleneck_conv2D (Co (None, 14, 14, 128)  40960       activation_44[0][0]
# __________________________________________________________________________________________________
# dense_2_2_bottleneck_bn (BatchN (None, 14, 14, 128)  512         dense_2_2_bottleneck_conv2D[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 14, 14, 128)  0           dense_2_2_bottleneck_bn[0][0]
# __________________________________________________________________________________________________
# dense_2_2_conv2D (Conv2D)       (None, 14, 14, 32)   36864       activation_45[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 14, 14, 352)  0           concatenate_20[0][0]
#                                                                  dense_2_2_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_2_3_bn (BatchNormalizatio (None, 14, 14, 352)  1408        concatenate_21[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 14, 14, 352)  0           dense_2_3_bn[0][0]
# __________________________________________________________________________________________________
# dense_2_3_bottleneck_conv2D (Co (None, 14, 14, 128)  45056       activation_46[0][0]
# __________________________________________________________________________________________________
# dense_2_3_bottleneck_bn (BatchN (None, 14, 14, 128)  512         dense_2_3_bottleneck_conv2D[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 14, 14, 128)  0           dense_2_3_bottleneck_bn[0][0]
# __________________________________________________________________________________________________
# dense_2_3_conv2D (Conv2D)       (None, 14, 14, 32)   36864       activation_47[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 14, 14, 384)  0           concatenate_21[0][0]
#                                                                  dense_2_3_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_2_4_bn (BatchNormalizatio (None, 14, 14, 384)  1536        concatenate_22[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 14, 14, 384)  0           dense_2_4_bn[0][0]
# __________________________________________________________________________________________________
# dense_2_4_bottleneck_conv2D (Co (None, 14, 14, 128)  49152       activation_48[0][0]
# __________________________________________________________________________________________________
# dense_2_4_bottleneck_bn (BatchN (None, 14, 14, 128)  512         dense_2_4_bottleneck_conv2D[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 14, 14, 128)  0           dense_2_4_bottleneck_bn[0][0]
# __________________________________________________________________________________________________
# dense_2_4_conv2D (Conv2D)       (None, 14, 14, 32)   36864       activation_49[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 14, 14, 416)  0           concatenate_22[0][0]
#                                                                  dense_2_4_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_2_5_bn (BatchNormalizatio (None, 14, 14, 416)  1664        concatenate_23[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 14, 14, 416)  0           dense_2_5_bn[0][0]
# __________________________________________________________________________________________________
# dense_2_5_bottleneck_conv2D (Co (None, 14, 14, 128)  53248       activation_50[0][0]
# __________________________________________________________________________________________________
# dense_2_5_bottleneck_bn (BatchN (None, 14, 14, 128)  512         dense_2_5_bottleneck_conv2D[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 14, 14, 128)  0           dense_2_5_bottleneck_bn[0][0]
# __________________________________________________________________________________________________
# dense_2_5_conv2D (Conv2D)       (None, 14, 14, 32)   36864       activation_51[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 14, 14, 448)  0           concatenate_23[0][0]
#                                                                  dense_2_5_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_2_6_bn (BatchNormalizatio (None, 14, 14, 448)  1792        concatenate_24[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 14, 14, 448)  0           dense_2_6_bn[0][0]
# __________________________________________________________________________________________________
# dense_2_6_bottleneck_conv2D (Co (None, 14, 14, 128)  57344       activation_52[0][0]
# __________________________________________________________________________________________________
# dense_2_6_bottleneck_bn (BatchN (None, 14, 14, 128)  512         dense_2_6_bottleneck_conv2D[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 14, 14, 128)  0           dense_2_6_bottleneck_bn[0][0]
# __________________________________________________________________________________________________
# dense_2_6_conv2D (Conv2D)       (None, 14, 14, 32)   36864       activation_53[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 14, 14, 480)  0           concatenate_24[0][0]
#                                                                  dense_2_6_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_2_7_bn (BatchNormalizatio (None, 14, 14, 480)  1920        concatenate_25[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 14, 14, 480)  0           dense_2_7_bn[0][0]
# __________________________________________________________________________________________________
# dense_2_7_bottleneck_conv2D (Co (None, 14, 14, 128)  61440       activation_54[0][0]
# __________________________________________________________________________________________________
# dense_2_7_bottleneck_bn (BatchN (None, 14, 14, 128)  512         dense_2_7_bottleneck_conv2D[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 14, 14, 128)  0           dense_2_7_bottleneck_bn[0][0]
# __________________________________________________________________________________________________
# dense_2_7_conv2D (Conv2D)       (None, 14, 14, 32)   36864       activation_55[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 14, 14, 512)  0           concatenate_25[0][0]
#                                                                  dense_2_7_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_2_8_bn (BatchNormalizatio (None, 14, 14, 512)  2048        concatenate_26[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 14, 14, 512)  0           dense_2_8_bn[0][0]
# __________________________________________________________________________________________________
# dense_2_8_bottleneck_conv2D (Co (None, 14, 14, 128)  65536       activation_56[0][0]
# __________________________________________________________________________________________________
# dense_2_8_bottleneck_bn (BatchN (None, 14, 14, 128)  512         dense_2_8_bottleneck_conv2D[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 14, 14, 128)  0           dense_2_8_bottleneck_bn[0][0]
# __________________________________________________________________________________________________
# dense_2_8_conv2D (Conv2D)       (None, 14, 14, 32)   36864       activation_57[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 14, 14, 544)  0           concatenate_26[0][0]
#                                                                  dense_2_8_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_2_9_bn (BatchNormalizatio (None, 14, 14, 544)  2176        concatenate_27[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 14, 14, 544)  0           dense_2_9_bn[0][0]
# __________________________________________________________________________________________________
# dense_2_9_bottleneck_conv2D (Co (None, 14, 14, 128)  69632       activation_58[0][0]
# __________________________________________________________________________________________________
# dense_2_9_bottleneck_bn (BatchN (None, 14, 14, 128)  512         dense_2_9_bottleneck_conv2D[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 14, 14, 128)  0           dense_2_9_bottleneck_bn[0][0]
# __________________________________________________________________________________________________
# dense_2_9_conv2D (Conv2D)       (None, 14, 14, 32)   36864       activation_59[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 14, 14, 576)  0           concatenate_27[0][0]
#                                                                  dense_2_9_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_2_10_bn (BatchNormalizati (None, 14, 14, 576)  2304        concatenate_28[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 14, 14, 576)  0           dense_2_10_bn[0][0]
# __________________________________________________________________________________________________
# dense_2_10_bottleneck_conv2D (C (None, 14, 14, 128)  73728       activation_60[0][0]
# __________________________________________________________________________________________________
# dense_2_10_bottleneck_bn (Batch (None, 14, 14, 128)  512         dense_2_10_bottleneck_conv2D[0][0
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 14, 14, 128)  0           dense_2_10_bottleneck_bn[0][0]
# __________________________________________________________________________________________________
# dense_2_10_conv2D (Conv2D)      (None, 14, 14, 32)   36864       activation_61[0][0]
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, 14, 14, 608)  0           concatenate_28[0][0]
#                                                                  dense_2_10_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_2_11_bn (BatchNormalizati (None, 14, 14, 608)  2432        concatenate_29[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 14, 14, 608)  0           dense_2_11_bn[0][0]
# __________________________________________________________________________________________________
# dense_2_11_bottleneck_conv2D (C (None, 14, 14, 128)  77824       activation_62[0][0]
# __________________________________________________________________________________________________
# dense_2_11_bottleneck_bn (Batch (None, 14, 14, 128)  512         dense_2_11_bottleneck_conv2D[0][0
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 14, 14, 128)  0           dense_2_11_bottleneck_bn[0][0]
# __________________________________________________________________________________________________
# dense_2_11_conv2D (Conv2D)      (None, 14, 14, 32)   36864       activation_63[0][0]
# __________________________________________________________________________________________________
# concatenate_30 (Concatenate)    (None, 14, 14, 640)  0           concatenate_29[0][0]
#                                                                  dense_2_11_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_2_12_bn (BatchNormalizati (None, 14, 14, 640)  2560        concatenate_30[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 14, 14, 640)  0           dense_2_12_bn[0][0]
# __________________________________________________________________________________________________
# dense_2_12_bottleneck_conv2D (C (None, 14, 14, 128)  81920       activation_64[0][0]
# ...
# __________________________________________________________________________________________________
# dense_3_6_bn (BatchNormalizatio (None, 7, 7, 704)    2816        concatenate_48[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, 7, 7, 704)    0           dense_3_6_bn[0][0]
# __________________________________________________________________________________________________
# dense_3_6_bottleneck_conv2D (Co (None, 7, 7, 128)    90112       activation_101[0][0]
# __________________________________________________________________________________________________
# dense_3_6_bottleneck_bn (BatchN (None, 7, 7, 128)    512         dense_3_6_bottleneck_conv2D[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, 7, 7, 128)    0           dense_3_6_bottleneck_bn[0][0]
# __________________________________________________________________________________________________
# dense_3_6_conv2D (Conv2D)       (None, 7, 7, 32)     36864       activation_102[0][0]
# __________________________________________________________________________________________________
# concatenate_49 (Concatenate)    (None, 7, 7, 736)    0           concatenate_48[0][0]
#                                                                  dense_3_6_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_3_7_bn (BatchNormalizatio (None, 7, 7, 736)    2944        concatenate_49[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, 7, 7, 736)    0           dense_3_7_bn[0][0]
# __________________________________________________________________________________________________
# dense_3_7_bottleneck_conv2D (Co (None, 7, 7, 128)    94208       activation_103[0][0]
# __________________________________________________________________________________________________
# dense_3_7_bottleneck_bn (BatchN (None, 7, 7, 128)    512         dense_3_7_bottleneck_conv2D[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 7, 7, 128)    0           dense_3_7_bottleneck_bn[0][0]
# __________________________________________________________________________________________________
# dense_3_7_conv2D (Conv2D)       (None, 7, 7, 32)     36864       activation_104[0][0]
# __________________________________________________________________________________________________
# concatenate_50 (Concatenate)    (None, 7, 7, 768)    0           concatenate_49[0][0]
#                                                                  dense_3_7_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_3_8_bn (BatchNormalizatio (None, 7, 7, 768)    3072        concatenate_50[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, 7, 7, 768)    0           dense_3_8_bn[0][0]
# __________________________________________________________________________________________________
# dense_3_8_bottleneck_conv2D (Co (None, 7, 7, 128)    98304       activation_105[0][0]
# __________________________________________________________________________________________________
# dense_3_8_bottleneck_bn (BatchN (None, 7, 7, 128)    512         dense_3_8_bottleneck_conv2D[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, 7, 7, 128)    0           dense_3_8_bottleneck_bn[0][0]
# __________________________________________________________________________________________________
# dense_3_8_conv2D (Conv2D)       (None, 7, 7, 32)     36864       activation_106[0][0]
# __________________________________________________________________________________________________
# concatenate_51 (Concatenate)    (None, 7, 7, 800)    0           concatenate_50[0][0]
#                                                                  dense_3_8_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_3_9_bn (BatchNormalizatio (None, 7, 7, 800)    3200        concatenate_51[0][0]
# __________________________________________________________________________________________________
# activation_107 (Activation)     (None, 7, 7, 800)    0           dense_3_9_bn[0][0]
# __________________________________________________________________________________________________
# dense_3_9_bottleneck_conv2D (Co (None, 7, 7, 128)    102400      activation_107[0][0]
# __________________________________________________________________________________________________
# dense_3_9_bottleneck_bn (BatchN (None, 7, 7, 128)    512         dense_3_9_bottleneck_conv2D[0][0]
# __________________________________________________________________________________________________
# activation_108 (Activation)     (None, 7, 7, 128)    0           dense_3_9_bottleneck_bn[0][0]
# __________________________________________________________________________________________________
# dense_3_9_conv2D (Conv2D)       (None, 7, 7, 32)     36864       activation_108[0][0]
# __________________________________________________________________________________________________
# concatenate_52 (Concatenate)    (None, 7, 7, 832)    0           concatenate_51[0][0]
#                                                                  dense_3_9_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_3_10_bn (BatchNormalizati (None, 7, 7, 832)    3328        concatenate_52[0][0]
# __________________________________________________________________________________________________
# activation_109 (Activation)     (None, 7, 7, 832)    0           dense_3_10_bn[0][0]
# __________________________________________________________________________________________________
# dense_3_10_bottleneck_conv2D (C (None, 7, 7, 128)    106496      activation_109[0][0]
# __________________________________________________________________________________________________
# dense_3_10_bottleneck_bn (Batch (None, 7, 7, 128)    512         dense_3_10_bottleneck_conv2D[0][0
# __________________________________________________________________________________________________
# activation_110 (Activation)     (None, 7, 7, 128)    0           dense_3_10_bottleneck_bn[0][0]
# __________________________________________________________________________________________________
# dense_3_10_conv2D (Conv2D)      (None, 7, 7, 32)     36864       activation_110[0][0]
# __________________________________________________________________________________________________
# concatenate_53 (Concatenate)    (None, 7, 7, 864)    0           concatenate_52[0][0]
#                                                                  dense_3_10_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_3_11_bn (BatchNormalizati (None, 7, 7, 864)    3456        concatenate_53[0][0]
# __________________________________________________________________________________________________
# activation_111 (Activation)     (None, 7, 7, 864)    0           dense_3_11_bn[0][0]
# __________________________________________________________________________________________________
# dense_3_11_bottleneck_conv2D (C (None, 7, 7, 128)    110592      activation_111[0][0]
# __________________________________________________________________________________________________
# dense_3_11_bottleneck_bn (Batch (None, 7, 7, 128)    512         dense_3_11_bottleneck_conv2D[0][0
# __________________________________________________________________________________________________
# activation_112 (Activation)     (None, 7, 7, 128)    0           dense_3_11_bottleneck_bn[0][0]
# __________________________________________________________________________________________________
# dense_3_11_conv2D (Conv2D)      (None, 7, 7, 32)     36864       activation_112[0][0]
# __________________________________________________________________________________________________
# concatenate_54 (Concatenate)    (None, 7, 7, 896)    0           concatenate_53[0][0]
#                                                                  dense_3_11_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_3_12_bn (BatchNormalizati (None, 7, 7, 896)    3584        concatenate_54[0][0]
# __________________________________________________________________________________________________
# activation_113 (Activation)     (None, 7, 7, 896)    0           dense_3_12_bn[0][0]
# __________________________________________________________________________________________________
# dense_3_12_bottleneck_conv2D (C (None, 7, 7, 128)    114688      activation_113[0][0]
# __________________________________________________________________________________________________
# dense_3_12_bottleneck_bn (Batch (None, 7, 7, 128)    512         dense_3_12_bottleneck_conv2D[0][0
# __________________________________________________________________________________________________
# activation_114 (Activation)     (None, 7, 7, 128)    0           dense_3_12_bottleneck_bn[0][0]
# __________________________________________________________________________________________________
# dense_3_12_conv2D (Conv2D)      (None, 7, 7, 32)     36864       activation_114[0][0]
# __________________________________________________________________________________________________
# concatenate_55 (Concatenate)    (None, 7, 7, 928)    0           concatenate_54[0][0]
#                                                                  dense_3_12_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_3_13_bn (BatchNormalizati (None, 7, 7, 928)    3712        concatenate_55[0][0]
# __________________________________________________________________________________________________
# activation_115 (Activation)     (None, 7, 7, 928)    0           dense_3_13_bn[0][0]
# __________________________________________________________________________________________________
# dense_3_13_bottleneck_conv2D (C (None, 7, 7, 128)    118784      activation_115[0][0]
# __________________________________________________________________________________________________
# dense_3_13_bottleneck_bn (Batch (None, 7, 7, 128)    512         dense_3_13_bottleneck_conv2D[0][0
# __________________________________________________________________________________________________
# activation_116 (Activation)     (None, 7, 7, 128)    0           dense_3_13_bottleneck_bn[0][0]
# __________________________________________________________________________________________________
# dense_3_13_conv2D (Conv2D)      (None, 7, 7, 32)     36864       activation_116[0][0]
# __________________________________________________________________________________________________
# concatenate_56 (Concatenate)    (None, 7, 7, 960)    0           concatenate_55[0][0]
#                                                                  dense_3_13_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_3_14_bn (BatchNormalizati (None, 7, 7, 960)    3840        concatenate_56[0][0]
# __________________________________________________________________________________________________
# activation_117 (Activation)     (None, 7, 7, 960)    0           dense_3_14_bn[0][0]
# __________________________________________________________________________________________________
# dense_3_14_bottleneck_conv2D (C (None, 7, 7, 128)    122880      activation_117[0][0]
# __________________________________________________________________________________________________
# dense_3_14_bottleneck_bn (Batch (None, 7, 7, 128)    512         dense_3_14_bottleneck_conv2D[0][0
# __________________________________________________________________________________________________
# activation_118 (Activation)     (None, 7, 7, 128)    0           dense_3_14_bottleneck_bn[0][0]
# __________________________________________________________________________________________________
# dense_3_14_conv2D (Conv2D)      (None, 7, 7, 32)     36864       activation_118[0][0]
# __________________________________________________________________________________________________
# concatenate_57 (Concatenate)    (None, 7, 7, 992)    0           concatenate_56[0][0]
#                                                                  dense_3_14_conv2D[0][0]
# __________________________________________________________________________________________________
# dense_3_15_bn (BatchNormalizati (None, 7, 7, 992)    3968        concatenate_57[0][0]
# __________________________________________________________________________________________________
# activation_119 (Activation)     (None, 7, 7, 992)    0           dense_3_15_bn[0][0]
# __________________________________________________________________________________________________
# dense_3_15_bottleneck_conv2D (C (None, 7, 7, 128)    126976      activation_119[0][0]
# __________________________________________________________________________________________________
# dense_3_15_bottleneck_bn (Batch (None, 7, 7, 128)    512         dense_3_15_bottleneck_conv2D[0][0
# __________________________________________________________________________________________________
# activation_120 (Activation)     (None, 7, 7, 128)    0           dense_3_15_bottleneck_bn[0][0]
# __________________________________________________________________________________________________
# dense_3_15_conv2D (Conv2D)      (None, 7, 7, 32)     36864       activation_120[0][0]
# __________________________________________________________________________________________________
# concatenate_58 (Concatenate)    (None, 7, 7, 1024)   0           concatenate_57[0][0]
#                                                                  dense_3_15_conv2D[0][0]
# __________________________________________________________________________________________________
# final_bn (BatchNormalization)   (None, 7, 7, 1024)   4096        concatenate_58[0][0]
# __________________________________________________________________________________________________
# activation_121 (Activation)     (None, 7, 7, 1024)   0           final_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 1024)         0           activation_121[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 14)           14350       global_average_pooling2d_1[0][0]
# ==================================================================================================
# Total params: 7,051,854
# Trainable params: 6,968,206
# Non-trainable params: 83,648
# __________________________________________________________________________________________________

# %%
# get diseases prediction and feature maps used for cam just as FYI
#  a cam image is class_weights[:, some_pathology]*conv_features[:,:,i]

from keras.models import Model
test_image_path = os.path.join(data_path, 'images','00000728_000.png') #.png 



cv2_image = cv2.resize(cv2.imread(test_image_path), (resized_height, resized_width))
predictions = model.predict(cv2_image[None,:,:,:])
predictions
conv_map_model = Model(inputs=model.input, outputs=model.get_layer(index=-3).output)
conv_features = conv_map_model.predict(cv2_image[None,:,:,:])
conv_features = conv_features[0, :, :, :] #np.squeeze(conv_features)
class_weights = model.layers[-1].get_weights()

plt.figure(figsize=(8,8))
imgplot = plt.imshow(cv2_image, cmap='gray')

# %%
def get_score_and_cam_picture(cv2_input_image, DenseNetImageNet121_model):
# based on https://github.com/jacobgil/keras-cam/blob/master/cam.py
    width, height, _ = cv2_input_image.shape
    class_weights = DenseNetImageNet121_model.layers[-1].get_weights()[0]
    final_conv_layer = DenseNetImageNet121_model.layers[-3]
    get_output = K.function([DenseNetImageNet121_model.layers[0].input], 
                            [final_conv_layer.output, \
                             DenseNetImageNet121_model.layers[-1].output])
    [conv_outputs, prediction] = get_output([cv2_input_image[None,:,:,:]])
    conv_outputs = conv_outputs[0, :, :, :]
    prediction = prediction[0,:]
    
    #Create the class activation map.
    predicted_disease = np.argmax(prediction)
    cam = np.zeros(dtype = np.float32, shape = conv_outputs.shape[:2])
    for i, w in enumerate(class_weights[:, predicted_disease]):
            cam += w * conv_outputs[:, :, i]
    
    return prediction, cam, predicted_disease


def process_cam_image(crt_cam_image, xray_image, crt_alpha = .5):
    im_width, im_height, _ = xray_image.shape
    crt_cam_image = cv2.resize(crt_cam_image, (im_width, im_height), \
                               interpolation=cv2.INTER_CUBIC)
    
#     do some gamma enhancement, e is too much
    crt_cam_image = np.power(1.1, crt_cam_image)
    crt_cam_image = normalize_nd_array(crt_cam_image)
    # crt_cam_image[np.where(crt_cam_image < 0.5)] = 0 
    crt_cam_image = 255*crt_cam_image

    # make cam an rgb image
    empty_image_channel = np.zeros(dtype = np.float32, shape = crt_cam_image.shape[:2])
    crt_cam_image = cv2.merge((crt_cam_image,empty_image_channel,empty_image_channel))
    
    blended_image = cv2.addWeighted(xray_image.astype('uint8'),crt_alpha,\
                                    crt_cam_image.astype('uint8'),(1-crt_alpha),0)
    return(blended_image)

def plot_cam_results(crt_blended_image, crt_cam_image, crt_xray_image, map_caption):
    import matplotlib.pyplot as plt

    fig = plt.figure(figsize = (15,7))

    ax1 = fig.add_subplot(2, 3, 1)
    ax1.imshow(crt_xray_image, cmap = 'gray', interpolation = 'bicubic')
    ax1.set_title('Orig X Ray')
    plt.axis('off')

    ax2 = fig.add_subplot(2,3, 2)
    cam_plot = ax2.imshow(crt_cam_image, cmap=plt.get_cmap('OrRd'), interpolation = 'bicubic')
    plt.colorbar(cam_plot, ax=ax2)
    ax2.set_title('Activation Map')
    plt.axis('off')

    ax3 = fig.add_subplot(2,3, 3)
    blended_plot = ax3.imshow(crt_blended_image, interpolation = 'bicubic')
    plt.colorbar(cam_plot, ax=ax3)
    ax3.set_title(map_caption)
    plt.axis('off')
    
    # serialize blended image plot padded in the x/y-direction
    import io
    image_as_BytesIO = io.BytesIO()
    x_direction_pad = 1.05;y_direction_pad=1.2
    extent = ax3.get_window_extent().transformed(fig.dpi_scale_trans.inverted())
    fig.savefig(image_as_BytesIO, 
                bbox_inches=extent.expanded(x_direction_pad, 
                                            y_direction_pad),
               format='png')
    image_as_BytesIO.seek(0)
    return(image_as_BytesIO)
    

    
def process_xray_image(crt_xray_image, DenseNetImageNet121_model):
    crt_xray_image = normalize_nd_array(crt_xray_image)
    crt_xray_image = 255*crt_xray_image
    crt_xray_image=crt_xray_image.astype('uint8')

    crt_predictions, crt_cam_image, predicted_disease_index = \
    get_score_and_cam_picture(crt_xray_image, 
                              DenseNetImageNet121_model)
    
    prj_consts = chestxray_consts()
    likely_disease=name_list[predicted_disease_index]
    likely_disease_prob = 100*crt_predictions[predicted_disease_index]
    likely_disease_prob_ratio=100*crt_predictions[predicted_disease_index]/sum(crt_predictions)
    print('predictions: ', crt_predictions)
    print('likely disease: ', likely_disease)
    print('likely disease prob: ', likely_disease_prob)
    print('likely disease prob ratio: ', likely_disease_prob_ratio)
    
    crt_blended_image = process_cam_image(crt_cam_image, crt_xray_image)
    plot_cam_results(crt_blended_image, crt_cam_image, crt_xray_image,
                    str(likely_disease)+ ' ' +
                    "{0:.1f}".format(likely_disease_prob)+ '% (weight ' +
                    "{0:.1f}".format(likely_disease_prob_ratio)+ '%)')
      

def normalize_nd_array(crt_array):
    # Normalised [0,1]
    crt_array = crt_array - np.min(crt_array)
    return(crt_array/np.ptp(crt_array))

# %%
# get diseases prediction and cam


cv2_image = normalize_nd_array(cv2_image)
cv2_image = 255*cv2_image
cv2_image=cv2_image.astype('uint8')

predictions, cam_image, predicted_disease_index = \
get_score_and_cam_picture(cv2_image, model)
predictions

name_list[predicted_disease_index]
print('likely disease: ', name_list[predicted_disease_index])
print('likely disease prob ratio: ', \
          predictions[predicted_disease_index]/sum(predictions))

blended_image = process_cam_image(cam_image, cv2_image)
plot_cam_results(blended_image, cam_image, cv2_image, \
                 name_list[predicted_disease_index])
# Out:
# likely disease:  Cardiomegaly
# likely disease prob ratio:  0.7359209110588707

# %% [markdown]
# # Exporting Models to ONNX and view model structure
#
# [Open Neural Network Exchange (ONNX)](http://onnx.ai/) provides an open source format for AI models, empowering AI developers to choose the right tools as their projects evolve. For example, you can train with your favorite framework (such as PyTorch), save your model in ONNX, then operationalize the model using another framework such as TensorFlow on the Azure ML platform.
#
# After exporting the model, you can visualize the ONNX model using a  [ONNX Viewer called Netron](https://lutzroeder.github.io/Netron/):
#
#
# ONNX exporter is a trace-based exporter. A trace-based exporter will execute your model once and export the relevant operators that are executed during the run. This is why we need to provide a &quot;dummy input&quot; in the export parameters so the model can be run using the input tensors.

# %%
# It is this simple using just 2 lines of code!
onnx_model = onnxmltools.convert_keras(model)
onnxmltools.utils.save_model(onnx_model, onnx_model_save_path)

# %%
# !ls $onnx_model_save_path
# Out:
# /mnt/xiaoyzhu/chestxray.onnx

# %% [markdown]
# You can also download the already converted onnx model from here: https://chestxray.blob.core.windows.net/chestxraytutorial/tutorial_xray/chestxray_converted.onnx
